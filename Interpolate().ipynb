# %%
import pandas as pd
df=pd.read_csv('D:\\Python\\ML\\Data.csv')

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       NaN
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df.interpolate()
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  59500.0       Yes
# 5   France  35.0  58000.0       NaN
# 6    Spain  41.5  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df.interpolate(method='linear')
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  59500.0       Yes
# 5   France  35.0  58000.0       NaN
# 6    Spain  41.5  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df.interpolate(method='index')
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  59500.0       Yes
# 5   France  35.0  58000.0       NaN
# 6    Spain  41.5  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df.interpolate(method='index')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9104\722817345.py in <module>
# ----> 1 df.interpolate(method='time')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#   10938         **kwargs,
#   10939     ) -> DataFrame | None:
# > 10940         return super().interpolate(
#   10941             method,
#   10942             axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    7039                 "those NaNs before interpolating."
#    7040             )
# -> 7041         new_data = obj._mgr.interpolate(
#    7042             method=method,
#    7043             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in interpolate(self, **kwargs)
#     357
#     358     def interpolate(self: T, **kwargs) -> T:
# --> 359         return self.apply("interpolate", **kwargs)
#     360
#     361     def shift(self: T, periods: int, axis: int, fill_value) -> T:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     302                     applied = b.apply(f, **kwargs)
#     303                 else:
# --> 304                     applied = getattr(b, f)(**kwargs)
#     305             except (TypeError, NotImplementedError):
#     306                 if not ignore_failures:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in interpolate(self, method, axis, index, inplace, limit, limit_direction, limit_area, fill_value, coerce, downcast, **kwargs)
#    1099         data = cast(np.ndarray, data)  # bc overridden by ExtensionBlock
#    1100
# -> 1101         missing.interpolate_array_2d(
#    1102             data,
#    1103             method=method,
#
# ~\anaconda3\lib\site-packages\pandas\core\missing.py in interpolate_array_2d(data, method, axis, index, limit, limit_direction, limit_area, fill_value, coerce, downcast, **kwargs)
#     247         assert index is not None  # for mypy
#     248
# --> 249         _interpolate_2d_with_fill(
#     250             data=data,
#     251             index=index,
#
# ~\anaconda3\lib\site-packages\pandas\core\missing.py in _interpolate_2d_with_fill(data, index, axis, method, limit, limit_direction, limit_area, fill_value, **kwargs)
#     290     if method == "time":
#     291         if not needs_i8_conversion(index.dtype):
# --> 292             raise ValueError(
#     293                 "time-weighted interpolation only works "
#     294                 "on Series or DataFrames with a "
#
# ValueError: time-weighted interpolation only works on Series or DataFrames with a DatetimeIndex

# %%
df=pd.read_csv('D:\\Python\\ML\\Data.csv',index_col='Country')

# %%
df
# Out:
#           Age   Salary Purchased
# Country
# France   44.0  72000.0        No
# Spain    27.0  48000.0       Yes
# Germany  30.0  54000.0        No
# Spain    38.0  61000.0        No
# Germany  40.0      NaN       Yes
# France   35.0  58000.0       NaN
# Spain     NaN  52000.0        No
# France   48.0  79000.0       Yes
# Germany  50.0  83000.0        No
# France   37.0  67000.0       Yes

# %%
df.interpolate(method='index')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9104\2515484856.py in <module>
# ----> 1 df.interpolate(method='index')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#   10938         **kwargs,
#   10939     ) -> DataFrame | None:
# > 10940         return super().interpolate(
#   10941             method,
#   10942             axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    7039                 "those NaNs before interpolating."
#    7040             )
# -> 7041         new_data = obj._mgr.interpolate(
#    7042             method=method,
#    7043             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in interpolate(self, **kwargs)
#     357
#     358     def interpolate(self: T, **kwargs) -> T:
# --> 359         return self.apply("interpolate", **kwargs)
#     360
#     361     def shift(self: T, periods: int, axis: int, fill_value) -> T:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     302                     applied = b.apply(f, **kwargs)
#     303                 else:
# --> 304                     applied = getattr(b, f)(**kwargs)
#     305             except (TypeError, NotImplementedError):
#     306                 if not ignore_failures:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in interpolate(self, method, axis, index, inplace, limit, limit_direction, limit_area, fill_value, coerce, downcast, **kwargs)
#    1099         data = cast(np.ndarray, data)  # bc overridden by ExtensionBlock
#    1100
# -> 1101         missing.interpolate_array_2d(
#    1102             data,
#    1103             method=method,
#
# ~\anaconda3\lib\site-packages\pandas\core\missing.py in interpolate_array_2d(data, method, axis, index, limit, limit_direction, limit_area, fill_value, coerce, downcast, **kwargs)
#     247         assert index is not None  # for mypy
#     248
# --> 249         _interpolate_2d_with_fill(
#     250             data=data,
#     251             index=index,
#
# ~\anaconda3\lib\site-packages\pandas\core\missing.py in _interpolate_2d_with_fill(data, index, axis, method, limit, limit_direction, limit_area, fill_value, **kwargs)
#     342     # Sequence[Sequence[Sequence[Sequence[_SupportsArray[dtype[<nothing>]]]]]]]]"
#     343     # interp each column independently
# --> 344     np.apply_along_axis(func, axis, data)  # type: ignore[arg-type]
#     345     return
#     346
#
# <__array_function__ internals> in apply_along_axis(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\shape_base.py in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     377             'Cannot apply_along_axis when any iteration dimensions are 0'
#     378         ) from None
# --> 379     res = asanyarray(func1d(inarr_view[ind0], *args, **kwargs))
#     380
#     381     # build a buffer for storing evaluations of func1d.
#
# ~\anaconda3\lib\site-packages\pandas\core\missing.py in func(yvalues)
#     322         # process 1-d slices in the axis direction
#     323
# --> 324         _interpolate_1d(
#     325             indices=indices,
#     326             yvalues=yvalues,
#
# ~\anaconda3\lib\site-packages\pandas\core\missing.py in _interpolate_1d(indices, yvalues, method, limit, limit_direction, limit_area, fill_value, bounds_error, order, **kwargs)
#     449
#     450         indexer = np.argsort(indices[valid])
# --> 451         yvalues[invalid] = np.interp(
#     452             indices[invalid], indices[valid][indexer], yvalues[valid][indexer]
#     453         )
#
# <__array_function__ internals> in interp(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in interp(x, xp, fp, left, right, period)
#    1437         fp = np.concatenate((fp[-1:], fp, fp[0:1]))
#    1438
# -> 1439     return interp_func(x, xp, fp, left, right)
#    1440
#    1441
#
# TypeError: Cannot cast array data from dtype('O') to dtype('float64') according to the rule 'safe'

# %%
df.interpolate(method='nearest')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9104\1654062127.py in <module>
# ----> 1 df.interpolate(method='nearest')
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#   10938         **kwargs,
#   10939     ) -> DataFrame | None:
# > 10940         return super().interpolate(
#   10941             method,
#   10942             axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    7039                 "those NaNs before interpolating."
#    7040             )
# -> 7041         new_data = obj._mgr.interpolate(
#    7042             method=method,
#    7043             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in interpolate(self, **kwargs)
#     357
#     358     def interpolate(self: T, **kwargs) -> T:
# --> 359         return self.apply("interpolate", **kwargs)
#     360
#     361     def shift(self: T, periods: int, axis: int, fill_value) -> T:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     302                     applied = b.apply(f, **kwargs)
#     303                 else:
# --> 304                     applied = getattr(b, f)(**kwargs)
#     305             except (TypeError, NotImplementedError):
#     306                 if not ignore_failures:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in interpolate(self, method, axis, index, inplace, limit, limit_direction, limit_area, fill_value, coerce, downcast, **kwargs)
#    1099         data = cast(np.ndarray, data)  # bc overridden by ExtensionBlock
#    1100
# -> 1101         missing.interpolate_array_2d(
#    1102             data,
#    1103             method=method,
#
# ~\anaconda3\lib\site-packages\pandas\core\missing.py in interpolate_array_2d(data, method, axis, index, limit, limit_direction, limit_area, fill_value, coerce, downcast, **kwargs)
#     247         assert index is not None  # for mypy
#     248
# --> 249         _interpolate_2d_with_fill(
#     250             data=data,
#     251             index=index,
#
# ~\anaconda3\lib\site-packages\pandas\core\missing.py in _interpolate_2d_with_fill(data, index, axis, method, limit, limit_direction, limit_area, fill_value, **kwargs)
#     342     # Sequence[Sequence[Sequence[Sequence[_SupportsArray[dtype[<nothing>]]]]]]]]"
#     343     # interp each column independently
# --> 344     np.apply_along_axis(func, axis, data)  # type: ignore[arg-type]
#     345     return
#     346
#
# <__array_function__ internals> in apply_along_axis(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\shape_base.py in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     377             'Cannot apply_along_axis when any iteration dimensions are 0'
#     378         ) from None
# --> 379     res = asanyarray(func1d(inarr_view[ind0], *args, **kwargs))
#     380
#     381     # build a buffer for storing evaluations of func1d.
#
# ~\anaconda3\lib\site-packages\pandas\core\missing.py in func(yvalues)
#     322         # process 1-d slices in the axis direction
#     323
# --> 324         _interpolate_1d(
#     325             indices=indices,
#     326             yvalues=yvalues,
#
# ~\anaconda3\lib\site-packages\pandas\core\missing.py in _interpolate_1d(indices, yvalues, method, limit, limit_direction, limit_area, fill_value, bounds_error, order, **kwargs)
#     453         )
#     454     else:
# --> 455         yvalues[invalid] = _interpolate_scipy_wrapper(
#     456             indices[valid],
#     457             yvalues[valid],
#
# ~\anaconda3\lib\site-packages\pandas\core\missing.py in _interpolate_scipy_wrapper(x, y, new_x, method, fill_value, bounds_error, order, **kwargs)
#     512         if method == "polynomial":
#     513             method = order
# --> 514         terp = interpolate.interp1d(
#     515             x, y, kind=method, fill_value=fill_value, bounds_error=bounds_error
#     516         )
#
# ~\anaconda3\lib\site-packages\scipy\interpolate\_interpolate.py in __init__(***failed resolving arguments***)
#     499                 # overflow
#     500                 self._side = 'left'
# --> 501                 self.x_bds = self.x / 2.0
#     502                 self.x_bds = self.x_bds[1:] + self.x_bds[:-1]
#     503
#
# TypeError: unsupported operand type(s) for /: 'str' and 'float'

# %%
df
# Out:
#           Age   Salary Purchased
# Country
# France   44.0  72000.0        No
# Spain    27.0  48000.0       Yes
# Germany  30.0  54000.0        No
# Spain    38.0  61000.0        No
# Germany  40.0      NaN       Yes
# France   35.0  58000.0       NaN
# Spain     NaN  52000.0        No
# France   48.0  79000.0       Yes
# Germany  50.0  83000.0        No
# France   37.0  67000.0       Yes

# %%
df=pd.read_csv('D:\\Python\\ML\\Data.csv')

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       NaN
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df.interpolate(method='polynomial',order=1)
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  59500.0       Yes
# 5   France  35.0  58000.0       NaN
# 6    Spain  41.5  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df.interpolate(method='polynomial',order=2)
# Out:
#    Country        Age        Salary Purchased
# 0   France  44.000000  72000.000000        No
# 1    Spain  27.000000  48000.000000       Yes
# 2  Germany  30.000000  54000.000000        No
# 3    Spain  38.000000  61000.000000        No
# 4  Germany  40.000000  62951.930932       Yes
# 5   France  35.000000  58000.000000       NaN
# 6    Spain  39.620828  52000.000000        No
# 7   France  48.000000  79000.000000       Yes
# 8  Germany  50.000000  83000.000000        No
# 9   France  37.000000  67000.000000       Yes

# %%
df.interpolate(method='spline',order=2)
# Out:
#    Country        Age        Salary Purchased
# 0   France  44.000000  72000.000000        No
# 1    Spain  27.000000  48000.000000       Yes
# 2  Germany  30.000000  54000.000000        No
# 3    Spain  38.000000  61000.000000        No
# 4  Germany  40.000000  62951.060388       Yes
# 5   France  35.000000  58000.000000       NaN
# 6    Spain  40.224241  52000.000000        No
# 7   France  48.000000  79000.000000       Yes
# 8  Germany  50.000000  83000.000000        No
# 9   France  37.000000  67000.000000       Yes

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       NaN
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df.interpolate()
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  59500.0       Yes
# 5   France  35.0  58000.0       NaN
# 6    Spain  41.5  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df.dtypes
# Out:
# Country       object
# Age          float64
# Salary       float64
# Purchased     object
# dtype: object

# %%
df.interpolate(limit=1)
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  59500.0       Yes
# 5   France  35.0  58000.0       NaN
# 6    Spain  41.5  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df.interpolate(limit=2)
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  59500.0       Yes
# 5   France  35.0  58000.0       NaN
# 6    Spain  41.5  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       NaN
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
df=pd.read_csv('D:\\Python\\ML\\Data.csv')

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany   NaN      NaN        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       NaN
# 6    Spain   NaN  52000.0        No
# 7   France  48.0      NaN       Yes
# 8  Germany  50.0  83000.0        No
# 9   France   NaN  67000.0       Yes

# %%
df.interpolate()
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  32.5  54500.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  59500.0       Yes
# 5   France  35.0  58000.0       NaN
# 6    Spain  41.5  52000.0        No
# 7   France  48.0  67500.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  50.0  67000.0       Yes

# %%
df.interpolate(limit=1,limit_direction='backward')
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  32.5  54500.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  59500.0       Yes
# 5   France  35.0  58000.0       NaN
# 6    Spain  41.5  52000.0        No
# 7   France  48.0  67500.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France   NaN  67000.0       Yes

# %%
df.interpolate(limit=2,limit_direction='backward')
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  32.5  54500.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  59500.0       Yes
# 5   France  35.0  58000.0       NaN
# 6    Spain  41.5  52000.0        No
# 7   France  48.0  67500.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France   NaN  67000.0       Yes

# %%
df.interpolate(limit=1,limit_direction='both')
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  32.5  54500.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  59500.0       Yes
# 5   France  35.0  58000.0       NaN
# 6    Spain  41.5  52000.0        No
# 7   France  48.0  67500.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  50.0  67000.0       Yes

# %%
df.interpolate(limit_area='inside')
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  32.5  54500.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  59500.0       Yes
# 5   France  35.0  58000.0       NaN
# 6    Spain  41.5  52000.0        No
# 7   France  48.0  67500.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France   NaN  67000.0       Yes

# %%
df.interpolate(limit_area='outside')
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany   NaN      NaN        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       NaN
# 6    Spain   NaN  52000.0        No
# 7   France  48.0      NaN       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  50.0  67000.0       Yes

# %%
df.interpolate(inplace=True)

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  32.5  54500.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  59500.0       Yes
# 5   France  35.0  58000.0       NaN
# 6    Spain  41.5  52000.0        No
# 7   France  48.0  67500.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  50.0  67000.0       Yes

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  32.5  54500.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  59500.0       Yes
# 5   France  35.0  58000.0       NaN
# 6    Spain  41.5  52000.0        No
# 7   France  48.0  67500.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  50.0  67000.0       Yes
