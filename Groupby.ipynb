# %%
import pandas as pd
df=pd.read_excel('titanic3.xls')

# %%
pd.DataFrame(df)
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
gr1=df.groupby(by='sex')

# %% [markdown]
# gr1

# %%
gr1.groups
# Out:
# {'female': [0, 2, 4, 6, 8, 11, 12, 13, 17, 18, 21, 23, 24, 27, 28, 32, 33, 35, 36, 41, 42, 43, 44, 48, 50, 55, 57, 59, 61, 63, 65, 66, 67, 69, 72, 73, 76, 78, 79, 82, 83, 85, 88, 90, 92, 95, 97, 98, 99, 102, 103, 104, 105, 107, 108, 111, 112, 113, 116, 117, 121, 122, 124, 127, 129, 130, 131, 134, 137, 139, 141, 144, 146, 149, 153, 155, 159, 160, 161, 163, 167, 168, 169, 176, 178, 180, 181, 182, 186, 187, 188, 190, 192, 193, 195, 198, 199, 204, 207, 208, ...], 'male': [1, 3, 5, 7, 9, 10, 14, 15, 16, 19, 20, 22, 25, 26, 29, 30, 31, 34, 37, 38, 39, 40, 45, 46, 47, 49, 51, 52, 53, 54, 56, 58, 60, 62, 64, 68, 70, 71, 74, 75, 77, 80, 81, 84, 86, 87, 89, 91, 93, 94, 96, 100, 101, 106, 109, 110, 114, 115, 118, 119, 120, 123, 125, 126, 128, 132, 133, 135, 136, 138, 140, 142, 143, 145, 147, 148, 150, 151, 152, 154, 156, 157, 158, 162, 164, 165, 166, 170, 171, 172, 173, 174, 175, 177, 179, 183, 184, 185, 189, 191, ...]}

# %%
gr2=df.groupby(by='age')

# %%
gr2.groups
# Out:
# {0.1667: [763], 0.3333: [747], 0.4167: [1240], 0.6667: [427], 0.75: [657, 658, 1111], 0.8333: [359, 548, 611], 0.9167: [1, 590], 1.0: [339, 478, 492, 762, 826, 895, 937, 1048, 1101, 1187], 2.0: [2, 514, 540, 587, 624, 866, 1096, 1103, 1144, 1156, 1209, 1230], 3.0: [479, 515, 549, 641, 734, 1098, 1112], 4.0: [94, 340, 588, 622, 894, 916, 934, 1142, 1189, 1206], 5.0: [591, 639, 643, 659, 794], 6.0: [273, 430, 623, 678, 1025, 1097], 7.0: [434, 1102, 1143, 1256], 8.0: [377, 385, 398, 541, 1099, 1145], 9.0: [627, 640, 679, 733, 807, 820, 825, 1082, 1208, 1257], 10.0: [828, 1141, 1207, 1265], 11.0: [54, 628, 827, 855], 11.5: [1263], 12.0: [341, 582, 1056], 13.0: [249, 501, 601, 642, 653], 14.0: [55, 513, 569, 830, 1057, 1105, 1236, 1279], 14.5: [1171, 1304], 15.0: [193, 350, 792, 1007, 1047, 1300], 16.0: [159, 187, 195, 416, 510, 602, 604, 709, 761, 787, 810, 818, 829, 1093, 1104, 1161, 1232, 1244, 1275], 17.0: [53, 92, 229, 295, 390, 458, 482, 625, 650, 700, 701, 738, 740, 755, 772, 791, 
# ...

# %%
df.groupby(['sex','age']).groups
# Out:
# {('female', 0.1667): [763], ('female', 0.75): [657, 658], ('female', 0.9167): [590], ('female', 1.0): [478, 895, 937, 1048, 1187], ('female', 2.0): [2, 540, 624, 866, 1156, 1209, 1230], ('female', 3.0): [479, 1098, 1112], ('female', 4.0): [340, 588, 916, 934, 1189], ('female', 5.0): [591, 643, 659, 794], ('female', 7.0): [434], ('female', 9.0): [627, 679, 807, 1208, 1257], ('female', 14.5): [1304], ('female', nan): [59, 69, 107, 108, 121, 134, 176, 204, 277, 293, 297, 382, 469, 483, 681, 682, 706, 757, 800, 819, 852, 856, 865, 872, 886, 901, 903, 922, 923, 928, 955, 956, 957, 958, 961, 984, 987, 993, 997, 999, 1001, 1002, 1004, 1006, 1012, 1013, 1014, 1023, 1028, 1036, 1037, 1039, 1042, 1043, 1044, 1054, 1071, 1076, 1077, 1078, 1081, 1095, 1122, 1123, 1124, 1136, 1149, 1151, 1159, 1172, 1173, 1174, 1175, 1180, 1198, 1216, 1247, 1305], ('female', 6.0): [430, 623], ('female', 8.0): [377, 541, 1099], ('female', 10.0): [828, 1265], ('female', 11.0): [628], ('female', 12.0): [341, 582], (
# ...

# %%
for age,df_1 in gr1:
    print(age)
    print(df_1)
# Out:
# female
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 2          1         0                     Allison, Miss. Helen Loraine
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
#
#          sex   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
list(gr1)
# Out:
# [('female',
#         pclass  survived                                             name  \
#   0          1         1                    Allen, Miss. Elisabeth Walton
#   2          1         0                     Allison, Miss. Helen Loraine
#   4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#   6          1         1                Andrews, Miss. Kornelia Theodosia
#   8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
#   ...      ...       ...                                              ...
#   1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
#   1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
#   1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
#   1304       3         0                             Zabour, Miss. Hileni
#   1305       3         0                            Zabour, Miss. Thamine
#
# ...

# %%
dict(list(gr1))
# Out:
# {'female':       pclass  survived                                             name  \
#  0          1         1                    Allen, Miss. Elisabeth Walton
#  2          1         0                     Allison, Miss. Helen Loraine
#  4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#  6          1         1                Andrews, Miss. Kornelia Theodosia
#  8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
#  ...      ...       ...                                              ...
#  1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
#  1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
#  1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
#  1304       3         0                             Zabour, Miss. Hileni
#  1305       3         0                            Zabour, Miss. Thamine
#
#           sex   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df.groupby('age').get_group(30)
# Out:
#       pclass  survived                                               name  \
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 32         1         1                            Bonnell, Miss. Caroline
# 67         1         1                               Cherry, Miss. Gladys
# 110        1         0                    Foreman, Mr. Benjamin Laventall
# 117        1         1                     Francatelli, Miss. Laura Mabel
# 182        1         1                                LeRoy, Miss. Bertha
# 191        1         0                         Loring, Mr. Joseph Holland
# 194        1         0                           Maguire, Mr. John Edward
# 209        1         1                           Mock, Mr. Philipp Edmund
# 230        1         1                              Perreault, Miss. Anne
# 258        1         1                            Serepeca, Miss. Augusta
# 323        2         0                                Abelson, Mr. Samuel
# ...

# %%
df.groupby('fare').get_group(50)
# Out:
#      pclass  survived                         name   sex   age  sibsp  parch  \
# 158       1         0  Hipkins, Mr. William Edward  male  55.0      0      0
# 241       1         0        Rood, Mr. Hugh Roscoe  male   NaN      0      0
#
#      ticket  fare cabin embarked boat  body            home.dest
# 158     680  50.0   C39        S  NaN   NaN  London / Birmingham
# 241  113767  50.0   A32        S  NaN   NaN          Seattle, WA

# %%
gr1=df.groupby('pclass').get_group(1)

# %% [markdown]
# #

# %%
gr1
# Out:
#      pclass  survived                                             name  \
# 0         1         1                    Allen, Miss. Elisabeth Walton
# 1         1         1                   Allison, Master. Hudson Trevor
# 2         1         0                     Allison, Miss. Helen Loraine
# 3         1         0             Allison, Mr. Hudson Joshua Creighton
# 4         1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ..      ...       ...                                              ...
# 318       1         0           Williams-Lambert, Mr. Fletcher Fellows
# 319       1         1                        Wilson, Miss. Helen Alice
# 320       1         1                                Woolner, Mr. Hugh
# 321       1         0                               Wright, Mr. George
# 322       1         1                         Young, Miss. Marie Grice
#
#         sex      age  sibsp  parch    ticket      fare    cabin embarked boat  \
# ...

# %%
gr1.sum()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12428\2871856081.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   gr1.sum()
# pclass                                                    323
# survived                                                  200
# name        Allen, Miss. Elisabeth WaltonAllison, Master. ...
# sex         femalemalefemalemalefemalemalefemalemalefemale...
# age                                                11121.4167
# sibsp                                                     141
# parch                                                     118
# fare                                               28265.4043
# body                                                   5699.0
# dtype: object

# %%
gr1.mean()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12428\1587183179.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   gr1.mean()
# pclass        1.000000
# survived      0.619195
# age          39.159918
# sibsp         0.436533
# parch         0.365325
# fare         87.508992
# body        162.828571
# dtype: float64

# %%
gr1.describe()
# Out:
#        pclass    survived         age       sibsp       parch        fare  \
# count   323.0  323.000000  284.000000  323.000000  323.000000  323.000000
# mean      1.0    0.619195   39.159918    0.436533    0.365325   87.508992
# std       0.0    0.486338   14.548059    0.609064    0.715602   80.447178
# min       1.0    0.000000    0.916700    0.000000    0.000000    0.000000
# 25%       1.0    0.000000   28.000000    0.000000    0.000000   30.695800
# 50%       1.0    1.000000   39.000000    0.000000    0.000000   60.000000
# 75%       1.0    1.000000   50.000000    1.000000    0.500000  107.662500
# max       1.0    1.000000   80.000000    3.000000    4.000000  512.329200
#
#              body
# count   35.000000
# mean   162.828571
# std     82.652172
# min     16.000000
# 25%    109.500000
# 50%    166.000000
# 75%    233.000000
# max    307.000000

# %%
gr1.agg(['sum','max','mean'])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_12428\398244739.py:1: FutureWarning: ['name', 'sex', 'ticket', 'cabin', 'embarked', 'boat', 'home.dest'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   gr1.agg(['sum','max','mean'])
#       pclass    survived                                               name  \
# sum    323.0  200.000000  Allen, Miss. Elisabeth WaltonAllison, Master. ...
# max      1.0    1.000000                           Young, Miss. Marie Grice
# mean     1.0    0.619195                                                NaN
#
#                                                     sex           age  \
# sum   femalemalefemalemalefemalemalefemalemalefemale...  11121.416700
# max                                                male     80.000000
# mean                                                NaN     39.159918
#
# ...
