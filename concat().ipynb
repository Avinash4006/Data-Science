# %%
import pandas as pd
s1=pd.Series([0,1,2])

# %%
s1
# Out:
# 0    0
# 1    1
# 2    2
# dtype: int64

# %%
s2=pd.Series([3,4,5,6,7])
s2
# Out:
# 0    3
# 1    4
# 2    5
# 3    6
# 4    7
# dtype: int64

# %%
pd.concat([s1,s2])
# Out:
# 0    0
# 1    1
# 2    2
# 0    3
# 1    4
# 2    5
# dtype: int64

# %%
pd.concat([s1,s2])
# Out:
# 0    0
# 1    1
# 2    2
# 0    3
# 1    4
# 2    5
# 3    6
# 4    7
# dtype: int64

# %%
df1=pd.DataFrame({'ID':[1,2,3,4],'Name':['A','B','C','D'],'Class':[5,6,7,8]})

# %% [markdown]
# #

# %%
df1
# Out:
#    ID Name  Class
# 0   1    A      5
# 1   2    B      6
# 2   3    C      7
# 3   4    D      8

# %%
df2=pd.DataFrame({'ID':[5,6,7,8],'Name':['E','F','G','H'],'Class':[9,10,11,12]})

# %%
df2
# Out:
#    ID Name  Class
# 0   5    E      9
# 1   6    F     10
# 2   7    G     11
# 3   8    H     12

# %%
pd.concat([df1,df2])
# Out:
#    ID Name  Class
# 0   1    A      5
# 1   2    B      6
# 2   3    C      7
# 3   4    D      8
# 0   5    E      9
# 1   6    F     10
# 2   7    G     11
# 3   8    H     12

# %%
pd.concat([df2,df1])
# Out:
#    ID Name  Class
# 0   5    E      9
# 1   6    F     10
# 2   7    G     11
# 3   8    H     12
# 0   1    A      5
# 1   2    B      6
# 2   3    C      7
# 3   4    D      8

# %%
pd.concat([df1,df2],axis=1)
# Out:
#    ID Name  Class  ID Name  Class
# 0   1    A      5   5    E      9
# 1   2    B      6   6    F     10
# 2   3    C      7   7    G     11
# 3   4    D      8   8    H     12

# %%
pd.concat([df1,df2],axis=0)
# Out:
#    ID Name  Class
# 0   1    A      5
# 1   2    B      6
# 2   3    C      7
# 3   4    D      8
# 0   5    E      9
# 1   6    F     10
# 2   7    G     11
# 3   8    H     12

# %%
pd.concat([df1,df2],axis=0,ignore_index=True)
# Out:
#    ID Name  Class
# 0   1    A      5
# 1   2    B      6
# 2   3    C      7
# 3   4    D      8
# 4   5    E      9
# 5   6    F     10
# 6   7    G     11
# 7   8    H     12

# %%
df3=pd.DataFrame({'ID':[3,4],'Name':['C','D'],'Class':[7,8]})

# %%
df3
# Out:
#    ID Name  Class
# 0   3    C      7
# 1   4    D      8

# %%
df1
# Out:
#    ID Name  Class
# 0   1    A      5
# 1   2    B      6
# 2   3    C      7
# 3   4    D      8

# %%
pd.concat([df1,df3])
# Out:
#    ID Name  Class
# 0   1    A      5
# 1   2    B      6
# 2   3    C      7
# 3   4    D      8
# 0   3    C      7
# 1   4    D      8

# %%
pd.concat([df1,df3],axis=1)
# Out:
#    ID Name  Class   ID Name  Class
# 0   1    A      5  3.0    C    7.0
# 1   2    B      6  4.0    D    8.0
# 2   3    C      7  NaN  NaN    NaN
# 3   4    D      8  NaN  NaN    NaN

# %%
pd.concat([df1,df3],axis=1,join='inner')
# Out:
#    ID Name  Class  ID Name  Class
# 0   1    A      5   3    C      7
# 1   2    B      6   4    D      8

# %%
pd.concat([df1,df3],keys=['df1','df3'])
# Out:
#        ID Name  Class
# df1 0   1    A      5
#     1   2    B      6
#     2   3    C      7
#     3   4    D      8
# df3 0   3    C      7
#     1   4    D      8

# %%
pd.concat([df1,df3],keys=['first df1','third df3'])
# Out:
#              ID Name  Class
# first df1 0   1    A      5
#           1   2    B      6
#           2   3    C      7
#           3   4    D      8
# third df3 0   3    C      7
#           1   4    D      8

# %%
pd.concat([df1,df3],axis=1,keys=['first df1','third df3'])
# Out:
#   first df1            third df3
#          ID Name Class        ID Name Class
# 0         1    A     5       3.0    C   7.0
# 1         2    B     6       4.0    D   8.0
# 2         3    C     7       NaN  NaN   NaN
# 3         4    D     8       NaN  NaN   NaN

# %%
df4=pd.DataFrame({'Marks':[10,20,40,50]})

# %%
df4
# Out:
#    Marks
# 0     10
# 1     20
# 2     40
# 3     50

# %%
pd.concat([df1,df4])
# Out:
#     ID Name  Class  Marks
# 0  1.0    A    5.0    NaN
# 1  2.0    B    6.0    NaN
# 2  3.0    C    7.0    NaN
# 3  4.0    D    8.0    NaN
# 0  NaN  NaN    NaN   10.0
# 1  NaN  NaN    NaN   20.0
# 2  NaN  NaN    NaN   40.0
# 3  NaN  NaN    NaN   50.0
