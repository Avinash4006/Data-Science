# %%
import pandas as pd
df=pd.read_csv('D:\\Python\\ML\\user_data1.csv')
df
# Out:
#           ID         Name  Age  Salary  Unnamed: 4 Date
# 0   15624510         Male   19   19000           0  Yes
# 1   15810944         Male   35   20000           0  Yes
# 2   15668575       Female   26   43000           0  Yes
# 3   15603246       Female   27   57000           0  Yes
# 4   15804002         Male   19   76000           0  Yes
# 5   15728773         Male   27   58000           0  Yes
# 6   15598044       Female   27   84000           0   No
# 7   15694829       Female   32  150000           1  Yes
# 8   15600575         Male   25   33000           0  Yes
# 9   15727311       Female   35   65000           0  Yes
# 10  15570769       Female   26   80000           0  Yes
# 11  15606274       Female   26   52000           0   No
# 12  15746139         Male   20   86000           0  Yes
# 13  15704987         Male   32   18000           0  Yes
# 14  15628972         Male   18   82000           0  Yes
# 15  15697686         Male   29   80000           0   No
# ...

# %%
df=pd.read_csv('D:\\Python\\ML\\user_data1.csv')
df
# Out:
#           ID         Name  Age  Salary  Unnamed: 4 Date
# 0   15624510         Male   19   19000           0  Yes
# 1   15810944         Male   35   20000           0  Yes
# 2   15668575       Female   26   43000           0  Yes
# 3   15603246          NaN   27   57000           0  Yes
# 4   15804002          NaN   19   76000           0  Yes
# 5   15728773          NaN   27   58000           0  Yes
# 6   15598044          NaN   27   84000           0   No
# 7   15694829          NaN   32  150000           1  Yes
# 8   15600575          NaN   25   33000           0  Yes
# 9   15727311       Female   35   65000           0  NaN
# 10  15570769       Female   26   80000           0  NaN
# 11  15606274       Female   26   52000           0   No
# 12  15746139         Male   20   86000           0  Yes
# 13  15704987         Male   32   18000           0  Yes
# 14  15628972         Male   18   82000           0  NaN
# 15  15697686         Male   29   80000           0   No
# ...

# %%
df=pd.read_csv('D:\\Python\\ML\\user_data1.csv')
df
# Out:
#           ID         Name  Age  Salary  Unnamed: 4       Date
# 0   15624510         Male   19   19000           0        Yes
# 1   15810944         Male   35   20000           0        Yes
# 2   15668575       Female   26   43000           0        Yes
# 3   15603246          NaN   27   57000           0        Yes
# 4   15804002          NaN   19   76000           0        Yes
# 5   15728773          NaN   27   58000           0        Yes
# 6   15598044          NaN   27   84000           0         No
# 7   15694829          NaN   32  150000           1        Yes
# 8   15600575          NaN   25   33000           0        Yes
# 9   15727311       Female   35   65000           0        NaN
# 10  15570769       Female   26   80000           0  Not avail
# 11  15606274       Female   26   52000           0         No
# 12  15746139         Male   20   86000           0        Yes
# 13  15704987         Male   32   18000           0        Yes
# ...

# %%
df=pd.read_csv('D:\\Python\\ML\\user_data1.csv',na_values='Not avail')
df
# Out:
#           ID         Name  Age  Salary  Unnamed: 4 Date
# 0   15624510         Male   19   19000           0  Yes
# 1   15810944         Male   35   20000           0  Yes
# 2   15668575       Female   26   43000           0  Yes
# 3   15603246          NaN   27   57000           0  Yes
# 4   15804002          NaN   19   76000           0  Yes
# 5   15728773          NaN   27   58000           0  Yes
# 6   15598044          NaN   27   84000           0   No
# 7   15694829          NaN   32  150000           1  Yes
# 8   15600575          NaN   25   33000           0  Yes
# 9   15727311       Female   35   65000           0  NaN
# 10  15570769       Female   26   80000           0  NaN
# 11  15606274       Female   26   52000           0   No
# 12  15746139         Male   20   86000           0  Yes
# 13  15704987         Male   32   18000           0  Yes
# 14  15628972         Male   18   82000           0  NaN
# 15  15697686         Male   29   80000           0   No
# ...

# %%
df=pd.read_csv('D:\\Python\\ML\\user_data1.csv',keep_default_na= True)
df
# Out:
#           ID         Name  Age  Salary  Unnamed: 4       Date
# 0   15624510         Male   19   19000           0        Yes
# 1   15810944         Male   35   20000           0        Yes
# 2   15668575       Female   26   43000           0        Yes
# 3   15603246          NaN   27   57000           0        Yes
# 4   15804002          NaN   19   76000           0        Yes
# 5   15728773          NaN   27   58000           0        Yes
# 6   15598044          NaN   27   84000           0         No
# 7   15694829          NaN   32  150000           1        Yes
# 8   15600575          NaN   25   33000           0        Yes
# 9   15727311       Female   35   65000           0        NaN
# 10  15570769       Female   26   80000           0  Not avail
# 11  15606274       Female   26   52000           0         No
# 12  15746139         Male   20   86000           0        Yes
# 13  15704987         Male   32   18000           0        Yes
# ...

# %%
df=pd.read_csv('user_data.csv')
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12648\4286818530.py in <module>
# ----> 1 df=pd.read_csv('user_data.csv')
#       2 df
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
df=pd.read_csv('user_data.csv',na_filter= False)
df
# Out:
#         User ID       Gender       Age      EstimatedSalary     Purchased
# 0      15624510         Male        19                  19000           0
# 1      15810944         Male        35                  20000           0
# 2      15668575       Female        26                  43000           0
# 3      15603246       Female        27                  57000           0
# 4      15804002         Male        19                  76000           0
# 5      15728773         Male        27                  58000           0
# 6      15598044       Female        27                  84000           0
# 7      15694829       Female        32                 150000           1
# 8      15600575         Male        25                  33000           0
# 9      15727311       Female        35                  65000           0
# 10     15570769       Female        26                  80000           0
# 11     15606274       Female        26                  52000           0
# ...

# %%
df.isnull()
# Out:
#         User ID       Gender       Age      EstimatedSalary     Purchased
# 0         False        False     False                  False       False
# 1         False        False     False                  False       False
# 2         False        False     False                  False       False
# 3         False        False     False                  False       False
# 4         False        False     False                  False       False
# 5         False        False     False                  False       False
# 6         False        False     False                  False       False
# 7         False        False     False                  False       False
# 8         False        False     False                  False       False
# 9         False        False     False                  False       False
# 10        False        False     False                  False       False
# 11        False        False     False                  False       False
# ...

# %%
df.isnull().sum()
# Out:
#     User ID              0
#      Gender              0
#      Age                 0
#     EstimatedSalary      0
#  Purchased               0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.notnull()
# Out:
#         User ID       Gender       Age      EstimatedSalary     Purchased
# 0          True         True      True                   True        True
# 1          True         True      True                   True        True
# 2          True         True      True                   True        True
# 3          True         True      True                   True        True
# 4          True         True      True                   True        True
# 5          True         True      True                   True        True
# 6          True         True      True                   True        True
# 7          True         True      True                   True        True
# 8          True         True      True                   True        True
# 9          True         True      True                   True        True
# 10         True         True      True                   True        True
# 11         True         True      True                   True        True
# ...

# %%
df.notnull().sum()
# Out:
#     User ID              22
#      Gender              22
#      Age                 22
#     EstimatedSalary      22
#  Purchased               22
# dtype: int64

# %%
df.notnull().sum().sum()
# Out:
# 110

# %%
#series
import numpy as np
s=pd.Series([1,2,3,np.nan,4,np.NAN])
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    NaN
# dtype: float64

# %%
s.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
s.isnull().sum()
# Out:
# 2

# %%
s.dropna()
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 4    4.0
# dtype: float64

# %%
s.dropna(axis=0)
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 4    4.0
# dtype: float64

# %%
s.dropna(how='all')
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 4    4.0
# dtype: float64
